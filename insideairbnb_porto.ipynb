# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
import sys
from insideairbnb_scrape import download_all_files, extract_all_gz_files

# %% [markdown]
# ### Downloading and extracting the tables
#
# uncomment the download_all_files and extract_all_gz_files functions

# %%
#function to iterate over dates and tables, downloading each file
#download_all_files()

#Extracts all .gz files in the specified directory
#extract_all_gz_files("porto_tables")

# %%
listings_2024_06_17_summary = pd.read_csv('./porto_tables/listings_summary_2024-06-17.csv')
listings_2024_06_17_summary.head(3)
# Out:
#                    id                         name    host_id  \
# 0            45168099  Beach & Walkways GuestHouse  364782402
# 1  859387906570209474             Estúdio Canidelo  507933510
# 2            44059520      Estudio centro do Porto  353219224
#
#          host_name neighbourhood_group  \
# 0             Sara       VILA DO CONDE
# 1             Dias   VILA NOVA DE GAIA
# 2  Porto Automatic               PORTO
#
#                                        neighbourhood  latitude  longitude  \
# 0                                             Árvore  41.33145   -8.73664
# 1                                           Canidelo  41.11544   -8.65838
# 2  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...  41.14835   -8.60907
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt  100.0               2                 39  2024-05-30
# 1  Entire home/apt  100.0               3                  2  2023-08-20
# ...

# %%
listings_2024_06_17 = pd.read_csv('./porto_tables/listings_2024-06-17.csv')
listings_2024_06_17.head(3)
# Out:
#                    id                                      listing_url  \
# 0            45168099            https://www.airbnb.com/rooms/45168099
# 1  859387906570209474  https://www.airbnb.com/rooms/859387906570209474
# 2            44059520            https://www.airbnb.com/rooms/44059520
#
#         scrape_id last_scraped       source                         name  \
# 0  20240617171802   2024-06-17  city scrape  Beach & Walkways GuestHouse
# 1  20240617171802   2024-06-17  city scrape             Estúdio Canidelo
# 2  20240617171802   2024-06-18  city scrape      Estudio centro do Porto
#
#                                          description  \
# 0  Completely renovated in July / 2020, this magn...
# 1  Simplify this quiet, centrally located space 3...
# 2  Fully equipped studio with small kitchnette, d...
#
#                                neighborhood_overview  \
# 0  This space is located next to Tree Beach.<br /...
# 1                                                NaN
# ...
